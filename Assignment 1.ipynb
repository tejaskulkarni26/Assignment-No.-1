# %% [markdown]
# # Assignment 1

# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\LENOVO\\Downloads\\Q7 (1).csv")
df.head()
# Out:
#           Unnamed: 0  Points  Score  Weight
# 0          Mazda RX4    3.90  2.620   16.46
# 1      Mazda RX4 Wag    3.90  2.875   17.02
# 2         Datsun 710    3.85  2.320   18.61
# 3     Hornet 4 Drive    3.08  3.215   19.44
# 4  Hornet Sportabout    3.15  3.440   17.02

# %%
import numpy as np
import pandas as pd
import scipy
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm

# %% [markdown]
# Q6) Calculate the Expected number of candies for a randomly selected child Below are the probabilities of count of candies for children (ignoring the nature of the child-Generalized view)
#
# Child A – probability of having 1 candy = 0.015 Child B – probability of having 4 candies = 0.20 Child C – probability of having 3 candies = 0.65 Child D – probability of having 5 candies = 0.005 Child E – probability of having 6 candies = 0.01 Child F – probability of having 2 candies = 0.120

# %%
#Ans: Expected number of candies for a randomly selected child :
import numpy as np
Probability=[0.015,0.20,0.65,0.005,0.01,0.120]
Candies_count=[1,4,3,5,6,2]
x=0
for i in Probability:
    for j in Candies_count:
        if Probability.index(i)==Candies_count.index(j):
            x=x+(i*j)
print(x)
# Out:
# 3.09

# %% [markdown]
# Q7) Calculate Mean, Median, Mode, Variance, Standard Deviation, Range & comment about the values / draw inferences, for the given dataset
#
# For Points,Score,Weigh> Find Mean, Median, Mode, Variance, Standard Deviation, and Range and also Comment about the values/ Draw some inferences.

# %%
df=pd.read_csv("C:\\Users\\LENOVO\\Downloads\\Q7 (1).csv")
print('Mean :\n', df.mean())
print('Median \n:', df.median())
print('Mode \n:', stats.mode(df))
print('Standard Deviation \n:', df.std())
print('Variance \n:', df.var())
print('Maximum Value \n:', df.max())
print('Minimum \n:', df.min())
print('Range is \n:',df.Points.max()-df.Points.min())
print(df.Score.max()-df.Score.min())
print(df.Weight.max()-df.Weight.min())

plt.boxplot(df.Points, vert=False)
plt.boxplot(df.Score, vert=False)
plt.boxplot(df.Weight, vert=False)
sns.jointplot(df.Points, kind='kde')
sns.jointplot(df.Score, kind='kde')
sns.jointplot(df.Weight, kind='kde')
'''Inferences:
by plotting jointplot, we can say the given data of points,scores, weights are shifted towards left and its tail on the right side,
it is a positively/right-skewed distribution.
by plotting boxplots of each columns we conclude that Score and Weight columns have some outliers on right side
Points and Weight dataset are a bimodal because it is having two modes and score is unimodal because it having single mode.'''
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_14080\4156202314.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print('Mean :\n', df.mean())
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_14080\4156202314.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print('Median \n:', df.median())
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_14080\4156202314.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print('Standard Deviation \n:', df.std())
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_14080\4156202314.py:6: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print('Variance \n:', df.var())
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Mean :
#  Points     3.596563
# Score      3.217250
# Weight    17.848750
# dtype: float64
# Median
# : Points     3.695
# Score      3.325
# Weight    17.710
# dtype: float64
# Mode
# : ModeResult(mode=array([['AMC Javelin', 3.07, 3.44, 17.02]], dtype=object), count=array([[1, 3, 3, 2]]))
# Standard Deviation
# : Points    0.534679
# Score     0.978457
# Weight    1.786943
# dtype: float64
# Variance
# : Points    0.285881
# Score     0.957379
# Weight    3.193166
# dtype: float64
# Maximum Value
# : Unnamed: 0    Volvo 142E
# Points              4.93
# Score              5.424
# Weight              22.9
# dtype: object
# Minimum
# : Unnamed: 0    AMC Javelin
# Points               2.76
# Score               1.513
# Weight               14.5
# dtype: object
# Range is
# : 2.17
# 3.9110000000000005
# 8.399999999999999
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 'Inferences:\nby plotting jointplot, we can say the given data of points,scores, weights are shifted towards left and its tail on the right side,\nit is a positively/right-skewed distribution.\nby plotting boxplots of each columns we conclude that Score and Weight columns have some outliers on right side\nPoints and Weight dataset are a bimodal because it is having two modes and score is unimodal because it having single mode.'

# %% [markdown]
# Q8) Calculate Expected Value for the problem below
# a)	The weights (X) of patients at a clinic (in pounds), are
# 108, 110, 123, 134, 135, 145, 167, 187, 199
# Assume one of the patients is chosen at random. What is the Expected Value of the Weight of that patient?

# %%
Weights=(108, 110, 123, 134, 135, 145, 167, 187, 199)
Expected_value=sum(Weights)/len(Weights)
print('Expected Value of the Weight of that patient is:', Expected_value)
# Out:
# Expected Value of the Weight of that patient is: 145.33333333333334

# %% [markdown]
# Q9) Calculate Skewness, Kurtosis & draw inferences on the following data
#       Cars speed and distance

# %%
#  A)  Index, Speed and Distance
Index=np.arange(1,51)
Speed=(4,4,7,7,8,9,10,10,10,11,11,12,12,12,12,13,13,13,13,14,14,14,14,15,15,15,16,16,17,17,17,18,18,18,18,19,19,19,20,20,20,20,20,22,23,24,24,24,24,25)
Dist=(2,10,4,22,16,10,18,26,34,17,28,14,20,24,28,26,34,34,46,26,36,60,80,20,26,54,32,40,32,40,50,42,56,76,84,36,46,68,32,48,52,56,64,66,54,70,92,93,120,85)
print('Skewness of Index is:', scipy.stats.skew(Index))
print('Skewness of Speed is:', scipy.stats.skew(Speed))
print('Skewness of Distance is:', scipy.stats.skew(Dist))
print('Kurtosis of Index is:', scipy.stats.kurtosis(Index))
print('Kurtosis of Speed is:', scipy.stats.kurtosis(Speed))
print('Kurtosis of Distance is:', scipy.stats.kurtosis(Dist))

sns.jointplot(Speed, kind='kde')
sns.jointplot(Dist, kind='kde')
plt.show()

'''Inference:
The given data of dist are shifted towards left and its tail on the right side, it is a positively/right-skewed distribution.
The given data of speed are shifted towards right and its tail on the left side, it is a negatively/left-skewed distribution.'''
# Out:
# Skewness of Index is: 0.0
# Skewness of Speed is: -0.11395477012828319
# Skewness of Distance is: 0.7824835173114966
# Kurtosis of Index is: -1.2009603841536614
# Kurtosis of Speed is: -0.5771474239437371
# Kurtosis of Distance is: 0.24801865717051808
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 'Inference:\nThe given data of dist are shifted towards left and its tail on the right side, it is a positively/right-skewed distribution.\nThe given data of speed are shifted towards right and its tail on the left side, it is a negatively/left-skewed distribution.'

# %%
#  B) SP and Weight(WT)
import pandas as pd
data=pd.read_csv("C:\\Users\\LENOVO\\Downloads\\Q9_b (1).csv")

print('Skewness of Index is:', scipy.stats.skew(data.SP))
print('Skewness of Speed is:', scipy.stats.skew(data.WT))
print('Kurtosis of Index is:', scipy.stats.kurtosis(data.SP))
print('Kurtosis of Speed is:', scipy.stats.kurtosis(data.WT))

plt.hist(data.SP, color='red')
plt.hist(data.WT, color='green')
plt.show()

'''Inference:
Most data points of SP are shifted towards left and its tail on the right side, it is a positively/right-skewed distribution.
Most data points of WT are shifted towards right and its tail on the left side, it is a negatively/left-skewed distribution.'''
# Out:
# Skewness of Index is: 1.5814536794423764
# Skewness of Speed is: -0.6033099322115126
# Kurtosis of Index is: 2.7235214865269244
# Kurtosis of Speed is: 0.8194658792266849
# 'Inference:\nMost data points of SP are shifted towards left and its tail on the right side, it is a positively/right-skewed distribution.\nMost data points of WT are shifted towards right and its tail on the left side, it is a negatively/left-skewed distribution.'

# %% [markdown]
# Q11)Suppose we want to estimate the average weight of an adult male in Mexico. We draw a random sample of 2,000 men from a population of 3,000,000 men and weight them. We find that the average person in our sample weights 200 pounds, and the standard deviation of the sample is 30 pounds. Calculate 94%,98%,96% confidence interval?

# %%
from scipy import stats
print('Confidence Interval for 94% is:', stats.norm.interval(0.94,200,30/(2000**0.5)))
print('Confidence Interval for 98% is:', stats.norm.interval(0.98,200,30/(2000**0.5)))
print('Confidence Interval for 96% is:', stats.norm.interval(0.96,200,30/(2000**0.5)))
# Out:
# Confidence Interval for 94% is: (198.738325292158, 201.261674707842)
# Confidence Interval for 98% is: (198.43943840429978, 201.56056159570022)
# Confidence Interval for 96% is: (198.62230334813333, 201.37769665186667)

# %% [markdown]
# Q12) Below are the scores obtained by a student in tests 34,36,36,38,38,39,39,40,40,41,41,41,41,42,42,45,49,56
#
# 1) Find mean, median, variance, standard deviation. 2) What can we say about the student marks?

# %%
#  1)
data=np.array([34,36,36,38,38,39,39,40,40,41,41,41,41,42,42,45,49,56])
mean=np.mean(data)
print('Mean is:', mean)
median=np.median(data)
print('Median is:', median)
var=np.var(data)
print('Variance is:', var)
std=np.std(data)
print('Standard Deviation is:', std)

plt.boxplot(data)
#plt.hist(data)
plt.show()

''' 2) from Histogram, we can say given data are shifted towards left and its tail on the right side, 
  it is a positively/right-skewed distribution. 
  from boxplot, we can say outliers are exists along right side of the boxplot.'''
# Out:
# Mean is: 41.0
# Median is: 40.5
# Variance is: 24.11111111111111
# Standard Deviation is: 4.910306620885412
# ' 2) from Histogram, we can say given data are shifted towards left and its tail on the right side, \n  it is a positively/right-skewed distribution. \n  from boxplot, we can say outliers are exists along right side of the boxplot.'

# %% [markdown]
# Q 20) Calculate probability from the given dataset for the below cases
# Calculate the probability of MPG  of Cars for the below cases.
#        MPG <- Cars$MPG
# a.	P(MPG>38)
# b.	P(MPG<40)
# c.  P (20<MPG<50)

# %%
car=pd.read_csv("C:\\Users\\LENOVO\\Downloads\\Cars.csv")
car_mpg = car['MPG']
car_mpg_mean = car.MPG.mean()
car_mpg_std = car.MPG.std()
print(car_mpg_mean)
print(car_mpg_std)

#P(MPG>38)
print('Probability for MPG>38 is:', 1-stats.norm.cdf(38,car_mpg_mean,car_mpg_std))

#P(MPG<40)
print('Probability for MPG<40 is:', stats.norm.cdf(40,car_mpg_mean,car_mpg_std))

#P(20<MPG<50)
mpg_20 = stats.norm.cdf(20,car.MPG.mean(),car.MPG.std())
mpg_50 = 1-stats.norm.cdf(50,car.MPG.mean(),car.MPG.std())
#print(mpg_20)
#print(mpg_50)
print('Probability for 20<MPG<50 is:',mpg_50-mpg_20)
# Out:
# 34.422075728024666
# 9.131444731795982
# Probability for MPG>38 is: 0.3475939251582705
# Probability for MPG<40 is: 0.7293498762151616
# Probability for 20<MPG<50 is: -0.013116469610523339

# %% [markdown]
# Q 21) Check whether the data follows normal distribution
# a)	Check whether the MPG of Cars follows Normal Distribution
#         Dataset: Cars.csv
#
#
# b)	Check Whether the Adipose Tissue (AT) and Waist Circumference(Waist)  from wc-at data set  follows Normal Distribution
#        Dataset: wc-at.csv

# %%
car=pd.read_csv("C:\\Users\\LENOVO\\Downloads\\Cars.csv")
car_mpg = car['MPG']
plt.hist(car_mpg)
plt.show()

# %%
wtat=pd.read_csv("C:\\Users\\LENOVO\\Downloads\\wc-at (1).csv")
#wtat.info()
#plt.plot(wtat.Waist)
#plt.plot(wtat.AT)
plt.plot(wtat.Waist,wtat.AT)
plt.show()

# Data does not follows  bell curve, data distributed randomly.
#Mean ≠ Median ≠ Mode

# %% [markdown]
# Q 22) Calculate the Z scores of 90% confidence interval,94% confidence interval, 60% confidence interval

# %%
#for 90% ,  
z_score = 1-0.90
print('Z_Score for 90 % is:', z_score)
#Z0.1 = 1.28  (Using Z-Table)
#For 94 % ,
z_score1 = (1-0.94)
print('Z_Score for 90 % is:', z_score1)
#Z0.06 = 1.55  (Using Z-Table)
#For 60% ,  
z_score2 = (1-0.60)
print('Z_Score for 90 % is:', z_score2)
#Z0.4 = 0.25  (Using Z-Table)
# Out:
# Z_Score for 90 % is: 0.09999999999999998
# Z_Score for 90 % is: 0.06000000000000005
# Z_Score for 90 % is: 0.4

# %% [markdown]
# Q 23) Calculate the t scores of 95% confidence interval, 96% confidence interval, 99% confidence interval for sample size of 25

# %%
t_score= (1-0.95)/2
print('t_score of 95% is:',t_score)
#t0.025= 2.060
t_score1= (1-0.96)/2
print('t_score of 96% is:',t_score1)
#t0.02= 2.485
t_score2= (1-0.99)/2
print('t_score of 99% is:',t_score2)
#t0.005= 2.787
# Out:
# t_score of 95% is: 0.025000000000000022
# t_score of 96% is: 0.020000000000000018
# t_score of 99% is: 0.0050000000000000044

# %% [markdown]
# Q 24) A Government company claims that an average light bulb lasts 270 days. A researcher randomly selects 18 bulbs for testing. The sampled bulbs last an average of 260 days, with a standard deviation of 90 days. If the CEO's claim were true, what is the probability that 18 randomly selected bulbs would have an average life of no more than 260 days Hint:
# rcode  pt(tscore,df)
# df  degrees of freedom

# %%
#H0= average life >= 260 days
#H1 = average life < 260 days
# tscore = x - µ / (ϭ / √n)
tscore = (260-270) / (90/ np.sqrt(18))
print('T_Score is', tscore)
p_value = stats.t.cdf(-0.4714, df = 17)
print('P_value is:', p_value)
# Out:
# T_Score is -0.4714045207910317
# P_value is: 0.32167411684460556
